# %% [markdown]
# # Data Science in Python for Beginners 🤓

# %% [markdown]
# ## Python Basics ⚙️

# %% [markdown]
#     Everything in Python is an object. Objects have attributes and methods.
# Real life example: a car as an object, has attributes such as color, make, year of manufacture, transmission mode etc., and methods such as accelerating, reverse, braking.

# %% [markdown]
# ### Python Data Types and Variables 🧱
# - Strings
# - Integers
# - Floats
# - Booleans & Logicals
# - Variables
# - Lists & Dictionaries*
# - "Built-in Methods"
# - None*
#
# *Only FYI

# %% [markdown]
# #### STRINGS   str()
# To represent a text and defined with "double" or 'single' quotes
#
#     "Python for Beginners"
#     'Python for Beginners'
#     '2019'

# %% [markdown]
# #### Built-in Methods for Strings
#     type("python")
#     int('2019')
#     len("python")
#     'python'.capitalize()
#     "python is fun".count('n')
#     "PYTHON".lower()
#     'python'.index('o')

# %% [markdown]
# #### Your turn! 🚀Try out `strings` below!
#
# How? Type in a line of code on the empty line below and press `Shift` + `enter/return ⏎` keys to run it

# %% [markdown]
# #### INTEGERS   int()
# To represent integers and can do standard arithmetics.
#
#     10
#     -24
#     2019

# %% [markdown]
# #### Built-in Methods for Integers
#     type(10)
#     abs(-24)
#     min(10, -24, 2019)
#     max(10, -24, 2019)
#     float(10)

# %% [markdown]
# #### Arithmetic Operators
#     1 + 2    => 3  (Addition)
#     1 - 2    => -1 (Subtraction)
#     2 * 4    => 8  (Multiplication)
#     5 / 2    => 2.5(Division)
#     5 // 2   => 2  (Floor division)
#     5 % 2    => 1  (Modulus)
#     2 ** 3   => 8  (Exponent)

# %% [markdown]
# #### FLOATS   float()
# To represent decimal numbers and can do standard arithmetics.
#
#     10.23132
#     -24.1
#     2019.0

# %% [markdown]
# #### Built-in Methods for Floats
#     all built-functions for integers
#     round(10.23132, 2)
#     import math # first import math package - a collection of advanced mathematical functions
#     math.floor(10.23132)
#     math.ceil(-24.1)
#     math.ceil(24.1)
#     math.factorial(5)

# %% [markdown]
# ####  Your turn! 🚀Try out `integers` and `floats` below!
#
# How? Type in a line of code on the empty line below and press `Shift` + `enter/return ⏎` keys to run it

# %% [markdown]
# #### BOOLEANS & LOGICALS   bool()
# Booleans represent something that is True or False
#
#     True
#     False
#
# Comparison Operators always yield Boolean values
#
#      ==       # different from assignment operator '='
#      !=
#      > or >=
#      < or <=
#
# Logicals include:
#
#     or
#     and
#     not

# %% [markdown]
# ### VARIABLES 📦
# - Allows you to store values to reuse later
# - You assign a value to a variable
# - Variables can be overwritten and incremented
# - By convention, variable names should be in snake_case
#
# Variable assignment statement - *putting things in a box*
#
#     putting the `string` "John" in the box `first_name`
#
#         first_name = "John"
#
#     putting the `integer` 29 in the box `age`
#
#         age = 29
#
#
# Variable reading - *opening the box to see what is inside*
#
#     print(age)
#     print(first_name)

# %% [markdown]
# ####  Your turn! 🚀Try out `booleans` and variables
#
# How? Type in a line of code on the empty line below and press `Shift` + `enter/return ⏎` keys to run it.
#
# Some ideas:
# * make two variables and check if they are equal (*pssst*, ==)
# * make two variables - your first name and last name - and try to add them together
# * create a variable with your age in years - now calculate your age in minutes

# %% [markdown]
# # !!! SPLITTING FROM MICHAEL'S HERE

# %% [markdown]
# # Data Science - Analysis 🧮

# %% [markdown]
# #### First of all - what are we using? 🔨

# %% [markdown]
# [Jupyter Notebook](https://jupyter.org) is an open-source web application which allows you to create and share documents with code, visualizations and narrative. Which is what we are doing right now!

# %% [markdown]
# [Numpy](https://www.numpy.org) fundamental package for scientific computing in Python.

# %% [markdown]
# [Pandas](https://pandas.pydata.org) is an open-source library providing easy to use data structuring and analytics for Python.

# %% [markdown]
# ### So this is how every Jupyter notebook starts...

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Python and Pandas is great for reading data files, like CSV

# %%
file = "countries of the world 2.csv"
countries_data = pd.read_csv(file, decimal=",")
# no need to use print() when we want to see DataFrames, simply put what you want to see on the last line
countries_data
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0            647500                        48.0                          0.00
# 1             28748                       124.6                          1.26
# 2           2381740                        13.8                          0.04
# 3               199                       290.4                         58.29
# 4               468                       152.1                          0.00
# ..              ...                         ...                           ...
# 222            5860                       419.9                          0.00
# 223          266000                         1.0                          0.42
# 224          527970                        40.6                          0.36
# 225          752614                        15.3                          0.00
# 226          390580                        31.3                          0.00
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0            23.06                              163.07               700.0
# 1            -4.93                               21.52              4500.0
# 2            -0.39                               31.00              6000.0
# 3           -20.71                                9.27              8000.0
# 4             6.60                                4.05             19000.0
# ..             ...                                 ...                 ...
# 222           2.98                               19.62               800.0
# 223            NaN                                 NaN                 NaN
# 224           0.00                               61.50               800.0
# 225           0.00                               88.29               800.0
# 226           0.00                               67.69              1900.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 0            36.0                3.2       12.13       0.22      87.65
# 1            86.5               71.2       21.09       4.42      74.49
# 2            70.0               78.1        3.22       0.25      96.53
# 3            97.0              259.5       10.00      15.00      75.00
# 4           100.0              497.2        2.22       0.00      97.78
# ..            ...                ...         ...        ...        ...
# 222           NaN              145.2       16.90      18.97      64.13
# 223           NaN                NaN        0.02       0.00      99.98
# 224          50.2               37.2        2.78       0.24      96.98
# 225          80.6                8.2        7.08       0.03      92.90
# 226          90.7               26.8        8.32       0.34      91.34
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 0        1.0      46.60      20.34        0.380     0.240    0.380
# 1        3.0      15.11       5.22        0.232     0.188    0.579
# 2        1.0      17.14       4.61        0.101     0.600    0.298
# 3        2.0      22.46       3.27          NaN       NaN      NaN
# 4        3.0       8.71       6.25          NaN       NaN      NaN
# ..       ...        ...        ...          ...       ...      ...
# 222      3.0      31.67       3.92        0.090     0.280    0.630
# 223      1.0        NaN        NaN          NaN       NaN    0.400
# 224      1.0      42.89       8.30        0.135     0.472    0.393
# 225      2.0      41.00      19.93        0.220     0.290    0.489
# 226      2.0      28.01      21.84        0.179     0.243    0.579
#
# [227 rows x 20 columns]

# %% [markdown]
# ## We can then have a quick look at our `DataFrame` 🗺

# %%
# check how many rows and columns we have (rows, columns)
print("rows and columns -->", countries_data.shape)
# check all the columns that our DataFrame has
print("all column names -->", countries_data.columns)
# check the first few records of the DataFrame
countries_data.head(5) # will take the first 5 records
# check the last few records of the DataFrame
countries_data.tail(5) # will take the last 5 records
# Out:
# rows and columns --> (227, 20)
# all column names --> Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')
#              Country                               Region  Population  \
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 222            5860                       419.9                          0.00
# 223          266000                         1.0                          0.42
# 224          527970                        40.6                          0.36
# 225          752614                        15.3                          0.00
# 226          390580                        31.3                          0.00
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 222           2.98                               19.62               800.0
# 223            NaN                                 NaN                 NaN
# 224           0.00                               61.50               800.0
# 225           0.00                               88.29               800.0
# 226           0.00                               67.69              1900.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 222           NaN              145.2       16.90      18.97      64.13
# 223           NaN                NaN        0.02       0.00      99.98
# 224          50.2               37.2        2.78       0.24      96.98
# 225          80.6                8.2        7.08       0.03      92.90
# 226          90.7               26.8        8.32       0.34      91.34
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 222      3.0      31.67       3.92        0.090     0.280    0.630
# 223      1.0        NaN        NaN          NaN       NaN    0.400
# 224      1.0      42.89       8.30        0.135     0.472    0.393
# 225      2.0      41.00      19.93        0.220     0.290    0.489
# 226      2.0      28.01      21.84        0.179     0.243    0.579

# %%
# we can see only the values of one column by putting the name of the column in square brackets, ie. ["column"]
countries_data["Population"]
# we can see a few values together with double square brackets, ie. [["column1", "column2"]]
countries_data[["Population", "Country"]]
# Out:
#      Population          Country
# 0      31056997     Afghanistan
# 1       3581655         Albania
# 2      32930091         Algeria
# 3         57794  American Samoa
# 4         71201         Andorra
# ..          ...              ...
# 222     2460492       West Bank
# 223      273008  Western Sahara
# 224    21456188           Yemen
# 225    11502010          Zambia
# 226    12236805        Zimbabwe
#
# [227 rows x 2 columns]

# %% [markdown]
# ####  Your turn! 🚀Run the code to import `numpy` and `pandas` and read the CSV to get `countrie_data`. No need to change anything there ;)
#
# #### Now play around with your `DataFrame` 🤓
#
# Some ideas:
# * check the amount of rows and columns in your DataFrame
# * check what are all the columns that you have
# * view only the "Climate" column of your DataFrame
# * view the first 10 rows of your DataFrame
# * view the last 10 rows of your DataFrame, but only viewing the "Country", "Population" and "Climate" 🤔
#
# How? Type in your code on the empty line below and press `Shift` + `enter/return ⏎` keys to run it

# %% [markdown]
# ## Now let's do some data analytics! 🔍

# %% [markdown]
# #### Let's say we want to see countries with over 20,000,000 people. We want to create a `boolean` - `True` or `False` - with this condition

# %%
large_population = countries_data["Population"] > 20_000_000
large_population
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 222    False
# 223    False
# 224     True
# 225    False
# 226    False
# Name: Population, Length: 227, dtype: bool

# %% [markdown]
# #### We can see that `large_population` is now a list of `True` and `False` values, matching our countries DataFrame 🧐

# %% [markdown]
# #### Now we can apply this condition to our `countries_data` using the square brackets `[condition]`, same syntax as we used for checking columns

# %%
large_countries = countries_data[large_population]
large_countries
# Out:
#                Country                               Region  Population  \
# 0         Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 2             Algeria   NORTHERN AFRICA                        32930091
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 11          Australia   OCEANIA                                20264082
# 16         Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 27             Brazil               LATIN AMER. & CARIB       188078227
# 32              Burma         ASIA (EX. NEAR EAST)             47382633
# 36             Canada   NORTHERN AMERICA                       33098932
# 42              China         ASIA (EX. NEAR EAST)           1313973713
# 43           Colombia               LATIN AMER. & CARIB        43593035
# 45   Congo, Dem. Rep.   SUB-SAHARAN AFRICA                     62660551
# 60              Egypt   NORTHERN AFRICA                        78887007
# 65           Ethiopia   SUB-SAHARAN AFRICA                     74777981
# 69             France   WESTERN EUROPE                         60876136
# 76            Germany   WESTERN EUROPE                         82422299
# 77              Ghana   SUB-SAHARAN AFRICA                     22409572
# 94              India         ASIA (EX. NEAR EAST)           1095351995
# 95          Indonesia         ASIA (EX. NEAR EAST)            245452739
# 96               Iran         ASIA (EX. NEAR EAST)             68688433
# 97               Iraq   NEAR EAST                              26783383
# 101             Italy   WESTERN EUROPE                         58133509
# 103             Japan         ASIA (EX. NEAR EAST)            127463611
# 107             Kenya   SUB-SAHARAN AFRICA                     34707817
# 109      Korea, North         ASIA (EX. NEAR EAST)             23113019
# 110      Korea, South         ASIA (EX. NEAR EAST)             48846823
# 126          Malaysia         ASIA (EX. NEAR EAST)             24385858
# 135            Mexico               LATIN AMER. & CARIB       107449525
# 141           Morocco   NORTHERN AFRICA                        33241259
# 145             Nepal         ASIA (EX. NEAR EAST)             28287147
# 152           Nigeria   SUB-SAHARAN AFRICA                    131859731
# 156          Pakistan         ASIA (EX. NEAR EAST)            165803560
# 161              Peru               LATIN AMER. & CARIB        28302603
# 162       Philippines         ASIA (EX. NEAR EAST)             89468677
# 163            Poland   EASTERN EUROPE                         38536869
# 168           Romania   EASTERN EUROPE                         22303552
# 169            Russia                  C.W. OF IND. STATES    142893540
# 179      Saudi Arabia   NEAR EAST                              27019731
# 189      South Africa   SUB-SAHARAN AFRICA                     44187637
# 190             Spain   WESTERN EUROPE                         40397842
# 191         Sri Lanka         ASIA (EX. NEAR EAST)             20222240
# 192             Sudan   SUB-SAHARAN AFRICA                     41236378
# 198            Taiwan         ASIA (EX. NEAR EAST)             23036087
# 200          Tanzania   SUB-SAHARAN AFRICA                     37445392
# 201          Thailand         ASIA (EX. NEAR EAST)             64631595
# 206            Turkey   NEAR EAST                              70413958
# 210            Uganda   SUB-SAHARAN AFRICA                     28195754
# 211           Ukraine                  C.W. OF IND. STATES     46710816
# 213    United Kingdom   WESTERN EUROPE                         60609153
# 214     United States   NORTHERN AMERICA                      298444215
# 216        Uzbekistan                  C.W. OF IND. STATES     27307134
# 218         Venezuela               LATIN AMER. & CARIB        25730435
# 219           Vietnam         ASIA (EX. NEAR EAST)             84402966
# 224             Yemen   NEAR EAST                              21456188
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0            647500                        48.0                          0.00
# 2           2381740                        13.8                          0.04
# 8           2766890                        14.4                          0.18
# 11          7686850                         2.6                          0.34
# 16           144000                      1023.4                          0.40
# 27          8511965                        22.1                          0.09
# 32           678500                        69.8                          0.28
# 36          9984670                         3.3                          2.02
# 42          9596960                       136.9                          0.15
# 43          1138910                        38.3                          0.28
# 45          2345410                        26.7                          0.00
# 60          1001450                        78.8                          0.24
# 65          1127127                        66.3                          0.00
# 69           547030                       111.3                          0.63
# 76           357021                       230.9                          0.67
# 77           239460                        93.6                          0.23
# 94          3287590                       333.2                          0.21
# 95          1919440                       127.9                          2.85
# 96          1648000                        41.7                          0.15
# 97           437072                        61.3                          0.01
# 101          301230                       193.0                          2.52
# 103          377835                       337.4                          7.87
# 107          582650                        59.6                          0.09
# 109          120540                       191.8                          2.07
# 110           98480                       496.0                          2.45
# 126          329750                        74.0                          1.42
# 135         1972550                        54.5                          0.47
# 141          446550                        74.4                          0.41
# 145          147181                       192.2                          0.00
# 152          923768                       142.7                          0.09
# 156          803940                       206.2                          0.13
# 161         1285220                        22.0                          0.19
# 162          300000                       298.2                         12.10
# 163          312685                       123.3                          0.16
# 168          237500                        93.9                          0.09
# 169        17075200                         8.4                          0.22
# 179         1960582                        13.8                          0.13
# 189         1219912                        36.2                          0.23
# 190          504782                        80.0                          0.98
# 191           65610                       308.2                          2.04
# 192         2505810                        16.5                          0.03
# 198           35980                       640.3                          4.35
# 200          945087                        39.6                          0.15
# 201          514000                       125.7                          0.63
# 206          780580                        90.2                          0.92
# 210          236040                       119.5                          0.00
# 211          603700                        77.4                          0.46
# 213          244820                       247.6                          5.08
# 214         9631420                        31.0                          0.21
# 216          447400                        61.0                          0.00
# 218          912050                        28.2                          0.31
# 219          329560                       256.1                          1.05
# 224          527970                        40.6                          0.36
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0            23.06                              163.07               700.0
# 2            -0.39                               31.00              6000.0
# 8             0.61                               15.18             11200.0
# 11            3.98                                4.69             29000.0
# 16           -0.71                               62.60              1900.0
# 27           -0.03                               29.61              7600.0
# 32           -1.80                               67.24              1800.0
# 36            5.96                                4.75             29800.0
# 42           -0.40                               24.18              5000.0
# 43           -0.31                               20.97              6300.0
# 45            0.00                               94.69               700.0
# 60           -0.22                               32.59              4000.0
# 65            0.00                               95.32               700.0
# 69            0.66                                4.26             27600.0
# 76            2.18                                4.16             27600.0
# 77           -0.64                               51.43              2200.0
# 94           -0.07                               56.29              2900.0
# 95            0.00                               35.60              3200.0
# 96           -0.84                               41.58              7000.0
# 97            0.00                               50.25              1500.0
# 101           2.07                                5.94             26700.0
# 103           0.00                                3.26             28200.0
# 107          -0.10                               61.47              1000.0
# 109           0.00                               24.04              1300.0
# 110           0.00                                7.05             17800.0
# 126           0.00                               17.70              9000.0
# 135          -4.87                               20.91              9000.0
# 141          -0.98                               41.62              4000.0
# 145           0.00                               66.98              1400.0
# 152           0.26                               98.80               900.0
# 156          -2.77                               72.44              2100.0
# 161          -1.05                               31.94              5100.0
# 162          -1.50                               23.51              4600.0
# 163          -0.49                                8.51             11100.0
# 168          -0.13                               26.43              7000.0
# 169           1.02                               15.39              8900.0
# 179          -2.71                               13.24             11800.0
# 189          -0.29                               61.81             10700.0
# 190           0.99                                4.42             22000.0
# 191          -1.31                               14.35              3700.0
# 192          -0.02                               62.50              1900.0
# 198           0.00                                6.40             23400.0
# 200          -2.06                               98.54               600.0
# 201           0.00                               20.48              7400.0
# 206           0.00                               41.04              6700.0
# 210           0.00                               67.83              1400.0
# 211          -0.39                               20.34              5400.0
# 213           2.19                                5.16             27700.0
# 214           3.41                                6.50             37800.0
# 216          -1.72                               71.10              1700.0
# 218          -0.04                               22.20              4800.0
# 219          -0.45                               25.95              2500.0
# 224           0.00                               61.50               800.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 0            36.0                3.2       12.13       0.22      87.65
# 2            70.0               78.1        3.22       0.25      96.53
# 8            97.1              220.4       12.31       0.48      87.21
# 11          100.0              565.5        6.55       0.04      93.41
# 16           43.1                7.3       62.11       3.07      34.82
# 27           86.4              225.3        6.96       0.90      92.15
# 32           85.3               10.1       15.19       0.97      83.84
# 36           97.0              552.2        4.96       0.02      95.02
# 42           90.9              266.7       15.40       1.25      83.35
# 43           92.5              176.2        2.42       1.67      95.91
# 45           65.5                0.2        2.96       0.52      96.52
# 60           57.7              131.8        2.87       0.48      96.65
# 65           42.7                8.2       10.71       0.75      88.54
# 69           99.0              586.4       33.53       2.07      64.40
# 76           99.0              667.9       33.85       0.59      65.56
# 77           74.8               14.4       16.26       9.67      74.07
# 94           59.5               45.4       54.40       2.74      42.86
# 95           87.9               52.0       11.32       7.23      81.45
# 96           79.4              276.4        8.72       1.39      89.89
# 97           40.4               38.6       13.15       0.78      86.07
# 101          98.6              430.9       27.79       9.53      62.68
# 103          99.0              461.2       12.19       0.96      86.85
# 107          85.1                8.1        8.08       0.98      90.94
# 109          99.0               42.4       20.76       2.49      76.75
# 110          97.9              486.1       17.18       1.95      80.87
# 126          88.7              179.0        5.48      17.61      76.91
# 135          92.2              181.6       12.99       1.31      85.70
# 141          51.7               40.4       19.61       2.17      78.22
# 145          45.2               15.9       21.68       0.64      77.68
# 152          68.0                9.3       31.29       2.96      65.75
# 156          45.7               31.8       27.87       0.87      71.26
# 161          90.9               79.5        2.89       0.40      96.71
# 162          92.6               38.4       18.95      16.77      64.28
# 163          99.8              306.3       45.91       1.12      52.97
# 168          98.4              196.9       40.82       2.25      56.93
# 169          99.6              280.6        7.33       0.11      92.56
# 179          78.8              140.6        1.67       0.09      98.24
# 189          86.4              107.0       12.08       0.79      87.13
# 190          97.9              453.5       26.07       9.87      64.06
# 191          92.3               61.5       13.86      15.70      70.44
# 192          61.1               16.3        6.83       0.18      92.99
# 198          96.1              591.0       24.00       1.00      75.00
# 200          78.2                4.0        4.52       1.08      94.40
# 201          92.6              108.9       29.36       6.46      64.18
# 206          86.5              269.5       30.93       3.31      65.76
# 210          69.9                3.6       25.88      10.65      63.47
# 211          99.7              259.9       56.21       1.61      42.18
# 213          99.0              543.5       23.46       0.21      76.33
# 214          97.0              898.0       19.13       0.22      80.65
# 216          99.3               62.9       10.83       0.83      88.34
# 218          93.4              140.1        2.95       0.92      96.13
# 219          90.3              187.7       19.97       5.95      74.08
# 224          50.2               37.2        2.78       0.24      96.98
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 0        1.0      46.60      20.34        0.380     0.240    0.380
# 2        1.0      17.14       4.61        0.101     0.600    0.298
# 8        3.0      16.73       7.55        0.095     0.358    0.547
# 11       1.0      12.14       7.51        0.038     0.262    0.700
# 16       2.0      29.80       8.27        0.199     0.198    0.603
# 27       2.0      16.56       6.17        0.084     0.400    0.516
# 32       2.0      17.91       9.83        0.564     0.082    0.353
# 36       NaN      10.78       7.80        0.022     0.294    0.684
# 42       1.5      13.25       6.97        0.125     0.473    0.403
# 43       2.0      20.48       5.58        0.125     0.342    0.533
# 45       2.0      43.69      13.27        0.550     0.110    0.340
# 60       1.0      22.94       5.23        0.149     0.357    0.493
# 65       2.0      37.98      14.86        0.475     0.099    0.426
# 69       4.0      11.99       9.14        0.022     0.214    0.764
# 76       3.0       8.25      10.62        0.009     0.296    0.695
# 77       2.0      30.52       9.72        0.366     0.246    0.387
# 94       2.5      22.01       8.18        0.186     0.276    0.538
# 95       2.0      20.34       6.25        0.134     0.458    0.408
# 96       1.0      17.00       5.55        0.116     0.424    0.460
# 97       1.0      31.98       5.37        0.073     0.666    0.261
# 101      NaN       8.72      10.40        0.021     0.291    0.688
# 103      3.0       9.37       9.16        0.017     0.258    0.725
# 107      1.5      39.72      14.02        0.163     0.188    0.651
# 109      3.0      15.54       7.13        0.300     0.340    0.360
# 110      3.0      10.00       5.85        0.033     0.403    0.563
# 126      2.0      22.86       5.05        0.084     0.480    0.436
# 135      1.5      20.69       4.74        0.038     0.259    0.702
# 141      NaN      21.98       5.58        0.217     0.357    0.426
# 145      NaN      30.98       9.31        0.380     0.210    0.410
# 152      1.5      40.43      16.94        0.269     0.487    0.244
# 156      1.0      29.74       8.23        0.216     0.251    0.533
# 161      1.5      20.48       6.23        0.080     0.270    0.650
# 162      2.0      24.89       5.41        0.144     0.326    0.530
# 163      3.0       9.85       9.89        0.050     0.311    0.640
# 168      3.0      10.70      11.77        0.101     0.350    0.549
# 169      NaN       9.95      14.65        0.054     0.371    0.575
# 179      1.0      29.34       2.58        0.033     0.613    0.354
# 189      1.0      18.20      22.00        0.025     0.303    0.671
# 190      3.0      10.06       9.72        0.040     0.295    0.665
# 191      2.0      15.51       6.52        0.178     0.276    0.545
# 192      2.0      34.53       8.97        0.387     0.203    0.410
# 198      2.0      12.56       6.48        0.018     0.259    0.723
# 200      NaN      37.71      16.39        0.432     0.172    0.396
# 201      2.0      13.87       7.04        0.099     0.441    0.460
# 206      3.0      16.62       5.97        0.117     0.298    0.585
# 210      2.0      47.35      12.24        0.311     0.222    0.469
# 211      3.0       8.82      14.39        0.187     0.452    0.361
# 213      3.0      10.71      10.13        0.005     0.237    0.758
# 214      3.0      14.14       8.26        0.010     0.204    0.787
# 216      1.0      26.36       7.84        0.342     0.229    0.430
# 218      2.0      18.71       4.92        0.040     0.419    0.541
# 219      2.0      16.86       6.22        0.209     0.410    0.381
# 224      1.0      42.89       8.30        0.135     0.472    0.393

# %%
# we can also sort our large_countries by Population, having largest first
large_countries.sort_values("Population", ascending=False) # change False to True if you wan't smallest countries first :)
# Out:
#                Country                               Region  Population  \
# 42              China         ASIA (EX. NEAR EAST)           1313973713
# 94              India         ASIA (EX. NEAR EAST)           1095351995
# 214     United States   NORTHERN AMERICA                      298444215
# 95          Indonesia         ASIA (EX. NEAR EAST)            245452739
# 27             Brazil               LATIN AMER. & CARIB       188078227
# 156          Pakistan         ASIA (EX. NEAR EAST)            165803560
# 16         Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 169            Russia                  C.W. OF IND. STATES    142893540
# 152           Nigeria   SUB-SAHARAN AFRICA                    131859731
# 103             Japan         ASIA (EX. NEAR EAST)            127463611
# 135            Mexico               LATIN AMER. & CARIB       107449525
# 162       Philippines         ASIA (EX. NEAR EAST)             89468677
# 219           Vietnam         ASIA (EX. NEAR EAST)             84402966
# 76            Germany   WESTERN EUROPE                         82422299
# 60              Egypt   NORTHERN AFRICA                        78887007
# 65           Ethiopia   SUB-SAHARAN AFRICA                     74777981
# 206            Turkey   NEAR EAST                              70413958
# 96               Iran         ASIA (EX. NEAR EAST)             68688433
# 201          Thailand         ASIA (EX. NEAR EAST)             64631595
# 45   Congo, Dem. Rep.   SUB-SAHARAN AFRICA                     62660551
# 69             France   WESTERN EUROPE                         60876136
# 213    United Kingdom   WESTERN EUROPE                         60609153
# 101             Italy   WESTERN EUROPE                         58133509
# 110      Korea, South         ASIA (EX. NEAR EAST)             48846823
# 32              Burma         ASIA (EX. NEAR EAST)             47382633
# 211           Ukraine                  C.W. OF IND. STATES     46710816
# 189      South Africa   SUB-SAHARAN AFRICA                     44187637
# 43           Colombia               LATIN AMER. & CARIB        43593035
# 192             Sudan   SUB-SAHARAN AFRICA                     41236378
# 190             Spain   WESTERN EUROPE                         40397842
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 163            Poland   EASTERN EUROPE                         38536869
# 200          Tanzania   SUB-SAHARAN AFRICA                     37445392
# 107             Kenya   SUB-SAHARAN AFRICA                     34707817
# 141           Morocco   NORTHERN AFRICA                        33241259
# 36             Canada   NORTHERN AMERICA                       33098932
# 2             Algeria   NORTHERN AFRICA                        32930091
# 0         Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 161              Peru               LATIN AMER. & CARIB        28302603
# 145             Nepal         ASIA (EX. NEAR EAST)             28287147
# 210            Uganda   SUB-SAHARAN AFRICA                     28195754
# 216        Uzbekistan                  C.W. OF IND. STATES     27307134
# 179      Saudi Arabia   NEAR EAST                              27019731
# 97               Iraq   NEAR EAST                              26783383
# 218         Venezuela               LATIN AMER. & CARIB        25730435
# 126          Malaysia         ASIA (EX. NEAR EAST)             24385858
# 109      Korea, North         ASIA (EX. NEAR EAST)             23113019
# 198            Taiwan         ASIA (EX. NEAR EAST)             23036087
# 77              Ghana   SUB-SAHARAN AFRICA                     22409572
# 168           Romania   EASTERN EUROPE                         22303552
# 224             Yemen   NEAR EAST                              21456188
# 11          Australia   OCEANIA                                20264082
# 191         Sri Lanka         ASIA (EX. NEAR EAST)             20222240
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 42          9596960                       136.9                          0.15
# 94          3287590                       333.2                          0.21
# 214         9631420                        31.0                          0.21
# 95          1919440                       127.9                          2.85
# 27          8511965                        22.1                          0.09
# 156          803940                       206.2                          0.13
# 16           144000                      1023.4                          0.40
# 169        17075200                         8.4                          0.22
# 152          923768                       142.7                          0.09
# 103          377835                       337.4                          7.87
# 135         1972550                        54.5                          0.47
# 162          300000                       298.2                         12.10
# 219          329560                       256.1                          1.05
# 76           357021                       230.9                          0.67
# 60          1001450                        78.8                          0.24
# 65          1127127                        66.3                          0.00
# 206          780580                        90.2                          0.92
# 96          1648000                        41.7                          0.15
# 201          514000                       125.7                          0.63
# 45          2345410                        26.7                          0.00
# 69           547030                       111.3                          0.63
# 213          244820                       247.6                          5.08
# 101          301230                       193.0                          2.52
# 110           98480                       496.0                          2.45
# 32           678500                        69.8                          0.28
# 211          603700                        77.4                          0.46
# 189         1219912                        36.2                          0.23
# 43          1138910                        38.3                          0.28
# 192         2505810                        16.5                          0.03
# 190          504782                        80.0                          0.98
# 8           2766890                        14.4                          0.18
# 163          312685                       123.3                          0.16
# 200          945087                        39.6                          0.15
# 107          582650                        59.6                          0.09
# 141          446550                        74.4                          0.41
# 36          9984670                         3.3                          2.02
# 2           2381740                        13.8                          0.04
# 0            647500                        48.0                          0.00
# 161         1285220                        22.0                          0.19
# 145          147181                       192.2                          0.00
# 210          236040                       119.5                          0.00
# 216          447400                        61.0                          0.00
# 179         1960582                        13.8                          0.13
# 97           437072                        61.3                          0.01
# 218          912050                        28.2                          0.31
# 126          329750                        74.0                          1.42
# 109          120540                       191.8                          2.07
# 198           35980                       640.3                          4.35
# 77           239460                        93.6                          0.23
# 168          237500                        93.9                          0.09
# 224          527970                        40.6                          0.36
# 11          7686850                         2.6                          0.34
# 191           65610                       308.2                          2.04
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 42           -0.40                               24.18              5000.0
# 94           -0.07                               56.29              2900.0
# 214           3.41                                6.50             37800.0
# 95            0.00                               35.60              3200.0
# 27           -0.03                               29.61              7600.0
# 156          -2.77                               72.44              2100.0
# 16           -0.71                               62.60              1900.0
# 169           1.02                               15.39              8900.0
# 152           0.26                               98.80               900.0
# 103           0.00                                3.26             28200.0
# 135          -4.87                               20.91              9000.0
# 162          -1.50                               23.51              4600.0
# 219          -0.45                               25.95              2500.0
# 76            2.18                                4.16             27600.0
# 60           -0.22                               32.59              4000.0
# 65            0.00                               95.32               700.0
# 206           0.00                               41.04              6700.0
# 96           -0.84                               41.58              7000.0
# 201           0.00                               20.48              7400.0
# 45            0.00                               94.69               700.0
# 69            0.66                                4.26             27600.0
# 213           2.19                                5.16             27700.0
# 101           2.07                                5.94             26700.0
# 110           0.00                                7.05             17800.0
# 32           -1.80                               67.24              1800.0
# 211          -0.39                               20.34              5400.0
# 189          -0.29                               61.81             10700.0
# 43           -0.31                               20.97              6300.0
# 192          -0.02                               62.50              1900.0
# 190           0.99                                4.42             22000.0
# 8             0.61                               15.18             11200.0
# 163          -0.49                                8.51             11100.0
# 200          -2.06                               98.54               600.0
# 107          -0.10                               61.47              1000.0
# 141          -0.98                               41.62              4000.0
# 36            5.96                                4.75             29800.0
# 2            -0.39                               31.00              6000.0
# 0            23.06                              163.07               700.0
# 161          -1.05                               31.94              5100.0
# 145           0.00                               66.98              1400.0
# 210           0.00                               67.83              1400.0
# 216          -1.72                               71.10              1700.0
# 179          -2.71                               13.24             11800.0
# 97            0.00                               50.25              1500.0
# 218          -0.04                               22.20              4800.0
# 126           0.00                               17.70              9000.0
# 109           0.00                               24.04              1300.0
# 198           0.00                                6.40             23400.0
# 77           -0.64                               51.43              2200.0
# 168          -0.13                               26.43              7000.0
# 224           0.00                               61.50               800.0
# 11            3.98                                4.69             29000.0
# 191          -1.31                               14.35              3700.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 42           90.9              266.7       15.40       1.25      83.35
# 94           59.5               45.4       54.40       2.74      42.86
# 214          97.0              898.0       19.13       0.22      80.65
# 95           87.9               52.0       11.32       7.23      81.45
# 27           86.4              225.3        6.96       0.90      92.15
# 156          45.7               31.8       27.87       0.87      71.26
# 16           43.1                7.3       62.11       3.07      34.82
# 169          99.6              280.6        7.33       0.11      92.56
# 152          68.0                9.3       31.29       2.96      65.75
# 103          99.0              461.2       12.19       0.96      86.85
# 135          92.2              181.6       12.99       1.31      85.70
# 162          92.6               38.4       18.95      16.77      64.28
# 219          90.3              187.7       19.97       5.95      74.08
# 76           99.0              667.9       33.85       0.59      65.56
# 60           57.7              131.8        2.87       0.48      96.65
# 65           42.7                8.2       10.71       0.75      88.54
# 206          86.5              269.5       30.93       3.31      65.76
# 96           79.4              276.4        8.72       1.39      89.89
# 201          92.6              108.9       29.36       6.46      64.18
# 45           65.5                0.2        2.96       0.52      96.52
# 69           99.0              586.4       33.53       2.07      64.40
# 213          99.0              543.5       23.46       0.21      76.33
# 101          98.6              430.9       27.79       9.53      62.68
# 110          97.9              486.1       17.18       1.95      80.87
# 32           85.3               10.1       15.19       0.97      83.84
# 211          99.7              259.9       56.21       1.61      42.18
# 189          86.4              107.0       12.08       0.79      87.13
# 43           92.5              176.2        2.42       1.67      95.91
# 192          61.1               16.3        6.83       0.18      92.99
# 190          97.9              453.5       26.07       9.87      64.06
# 8            97.1              220.4       12.31       0.48      87.21
# 163          99.8              306.3       45.91       1.12      52.97
# 200          78.2                4.0        4.52       1.08      94.40
# 107          85.1                8.1        8.08       0.98      90.94
# 141          51.7               40.4       19.61       2.17      78.22
# 36           97.0              552.2        4.96       0.02      95.02
# 2            70.0               78.1        3.22       0.25      96.53
# 0            36.0                3.2       12.13       0.22      87.65
# 161          90.9               79.5        2.89       0.40      96.71
# 145          45.2               15.9       21.68       0.64      77.68
# 210          69.9                3.6       25.88      10.65      63.47
# 216          99.3               62.9       10.83       0.83      88.34
# 179          78.8              140.6        1.67       0.09      98.24
# 97           40.4               38.6       13.15       0.78      86.07
# 218          93.4              140.1        2.95       0.92      96.13
# 126          88.7              179.0        5.48      17.61      76.91
# 109          99.0               42.4       20.76       2.49      76.75
# 198          96.1              591.0       24.00       1.00      75.00
# 77           74.8               14.4       16.26       9.67      74.07
# 168          98.4              196.9       40.82       2.25      56.93
# 224          50.2               37.2        2.78       0.24      96.98
# 11          100.0              565.5        6.55       0.04      93.41
# 191          92.3               61.5       13.86      15.70      70.44
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 42       1.5      13.25       6.97        0.125     0.473    0.403
# 94       2.5      22.01       8.18        0.186     0.276    0.538
# 214      3.0      14.14       8.26        0.010     0.204    0.787
# 95       2.0      20.34       6.25        0.134     0.458    0.408
# 27       2.0      16.56       6.17        0.084     0.400    0.516
# 156      1.0      29.74       8.23        0.216     0.251    0.533
# 16       2.0      29.80       8.27        0.199     0.198    0.603
# 169      NaN       9.95      14.65        0.054     0.371    0.575
# 152      1.5      40.43      16.94        0.269     0.487    0.244
# 103      3.0       9.37       9.16        0.017     0.258    0.725
# 135      1.5      20.69       4.74        0.038     0.259    0.702
# 162      2.0      24.89       5.41        0.144     0.326    0.530
# 219      2.0      16.86       6.22        0.209     0.410    0.381
# 76       3.0       8.25      10.62        0.009     0.296    0.695
# 60       1.0      22.94       5.23        0.149     0.357    0.493
# 65       2.0      37.98      14.86        0.475     0.099    0.426
# 206      3.0      16.62       5.97        0.117     0.298    0.585
# 96       1.0      17.00       5.55        0.116     0.424    0.460
# 201      2.0      13.87       7.04        0.099     0.441    0.460
# 45       2.0      43.69      13.27        0.550     0.110    0.340
# 69       4.0      11.99       9.14        0.022     0.214    0.764
# 213      3.0      10.71      10.13        0.005     0.237    0.758
# 101      NaN       8.72      10.40        0.021     0.291    0.688
# 110      3.0      10.00       5.85        0.033     0.403    0.563
# 32       2.0      17.91       9.83        0.564     0.082    0.353
# 211      3.0       8.82      14.39        0.187     0.452    0.361
# 189      1.0      18.20      22.00        0.025     0.303    0.671
# 43       2.0      20.48       5.58        0.125     0.342    0.533
# 192      2.0      34.53       8.97        0.387     0.203    0.410
# 190      3.0      10.06       9.72        0.040     0.295    0.665
# 8        3.0      16.73       7.55        0.095     0.358    0.547
# 163      3.0       9.85       9.89        0.050     0.311    0.640
# 200      NaN      37.71      16.39        0.432     0.172    0.396
# 107      1.5      39.72      14.02        0.163     0.188    0.651
# 141      NaN      21.98       5.58        0.217     0.357    0.426
# 36       NaN      10.78       7.80        0.022     0.294    0.684
# 2        1.0      17.14       4.61        0.101     0.600    0.298
# 0        1.0      46.60      20.34        0.380     0.240    0.380
# 161      1.5      20.48       6.23        0.080     0.270    0.650
# 145      NaN      30.98       9.31        0.380     0.210    0.410
# 210      2.0      47.35      12.24        0.311     0.222    0.469
# 216      1.0      26.36       7.84        0.342     0.229    0.430
# 179      1.0      29.34       2.58        0.033     0.613    0.354
# 97       1.0      31.98       5.37        0.073     0.666    0.261
# 218      2.0      18.71       4.92        0.040     0.419    0.541
# 126      2.0      22.86       5.05        0.084     0.480    0.436
# 109      3.0      15.54       7.13        0.300     0.340    0.360
# 198      2.0      12.56       6.48        0.018     0.259    0.723
# 77       2.0      30.52       9.72        0.366     0.246    0.387
# 168      3.0      10.70      11.77        0.101     0.350    0.549
# 224      1.0      42.89       8.30        0.135     0.472    0.393
# 11       1.0      12.14       7.51        0.038     0.262    0.700
# 191      2.0      15.51       6.52        0.178     0.276    0.545

# %%
# but we can also combine data points! Let's see which of our large countries have the biggest Service industry 🤔
large_service_countries = large_countries.sort_values("Service", ascending=False)
large_service_countries
# Out:
#                Country                               Region  Population  \
# 214     United States   NORTHERN AMERICA                      298444215
# 69             France   WESTERN EUROPE                         60876136
# 213    United Kingdom   WESTERN EUROPE                         60609153
# 103             Japan         ASIA (EX. NEAR EAST)            127463611
# 198            Taiwan         ASIA (EX. NEAR EAST)             23036087
# 135            Mexico               LATIN AMER. & CARIB       107449525
# 11          Australia   OCEANIA                                20264082
# 76            Germany   WESTERN EUROPE                         82422299
# 101             Italy   WESTERN EUROPE                         58133509
# 36             Canada   NORTHERN AMERICA                       33098932
# 189      South Africa   SUB-SAHARAN AFRICA                     44187637
# 190             Spain   WESTERN EUROPE                         40397842
# 107             Kenya   SUB-SAHARAN AFRICA                     34707817
# 161              Peru               LATIN AMER. & CARIB        28302603
# 163            Poland   EASTERN EUROPE                         38536869
# 16         Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 206            Turkey   NEAR EAST                              70413958
# 169            Russia                  C.W. OF IND. STATES    142893540
# 110      Korea, South         ASIA (EX. NEAR EAST)             48846823
# 168           Romania   EASTERN EUROPE                         22303552
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 191         Sri Lanka         ASIA (EX. NEAR EAST)             20222240
# 218         Venezuela               LATIN AMER. & CARIB        25730435
# 94              India         ASIA (EX. NEAR EAST)           1095351995
# 156          Pakistan         ASIA (EX. NEAR EAST)            165803560
# 43           Colombia               LATIN AMER. & CARIB        43593035
# 162       Philippines         ASIA (EX. NEAR EAST)             89468677
# 27             Brazil               LATIN AMER. & CARIB       188078227
# 60              Egypt   NORTHERN AFRICA                        78887007
# 210            Uganda   SUB-SAHARAN AFRICA                     28195754
# 96               Iran         ASIA (EX. NEAR EAST)             68688433
# 201          Thailand         ASIA (EX. NEAR EAST)             64631595
# 126          Malaysia         ASIA (EX. NEAR EAST)             24385858
# 216        Uzbekistan                  C.W. OF IND. STATES     27307134
# 141           Morocco   NORTHERN AFRICA                        33241259
# 65           Ethiopia   SUB-SAHARAN AFRICA                     74777981
# 145             Nepal         ASIA (EX. NEAR EAST)             28287147
# 192             Sudan   SUB-SAHARAN AFRICA                     41236378
# 95          Indonesia         ASIA (EX. NEAR EAST)            245452739
# 42              China         ASIA (EX. NEAR EAST)           1313973713
# 200          Tanzania   SUB-SAHARAN AFRICA                     37445392
# 224             Yemen   NEAR EAST                              21456188
# 77              Ghana   SUB-SAHARAN AFRICA                     22409572
# 219           Vietnam         ASIA (EX. NEAR EAST)             84402966
# 0         Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 211           Ukraine                  C.W. OF IND. STATES     46710816
# 109      Korea, North         ASIA (EX. NEAR EAST)             23113019
# 179      Saudi Arabia   NEAR EAST                              27019731
# 32              Burma         ASIA (EX. NEAR EAST)             47382633
# 45   Congo, Dem. Rep.   SUB-SAHARAN AFRICA                     62660551
# 2             Algeria   NORTHERN AFRICA                        32930091
# 97               Iraq   NEAR EAST                              26783383
# 152           Nigeria   SUB-SAHARAN AFRICA                    131859731
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 214         9631420                        31.0                          0.21
# 69           547030                       111.3                          0.63
# 213          244820                       247.6                          5.08
# 103          377835                       337.4                          7.87
# 198           35980                       640.3                          4.35
# 135         1972550                        54.5                          0.47
# 11          7686850                         2.6                          0.34
# 76           357021                       230.9                          0.67
# 101          301230                       193.0                          2.52
# 36          9984670                         3.3                          2.02
# 189         1219912                        36.2                          0.23
# 190          504782                        80.0                          0.98
# 107          582650                        59.6                          0.09
# 161         1285220                        22.0                          0.19
# 163          312685                       123.3                          0.16
# 16           144000                      1023.4                          0.40
# 206          780580                        90.2                          0.92
# 169        17075200                         8.4                          0.22
# 110           98480                       496.0                          2.45
# 168          237500                        93.9                          0.09
# 8           2766890                        14.4                          0.18
# 191           65610                       308.2                          2.04
# 218          912050                        28.2                          0.31
# 94          3287590                       333.2                          0.21
# 156          803940                       206.2                          0.13
# 43          1138910                        38.3                          0.28
# 162          300000                       298.2                         12.10
# 27          8511965                        22.1                          0.09
# 60          1001450                        78.8                          0.24
# 210          236040                       119.5                          0.00
# 96          1648000                        41.7                          0.15
# 201          514000                       125.7                          0.63
# 126          329750                        74.0                          1.42
# 216          447400                        61.0                          0.00
# 141          446550                        74.4                          0.41
# 65          1127127                        66.3                          0.00
# 145          147181                       192.2                          0.00
# 192         2505810                        16.5                          0.03
# 95          1919440                       127.9                          2.85
# 42          9596960                       136.9                          0.15
# 200          945087                        39.6                          0.15
# 224          527970                        40.6                          0.36
# 77           239460                        93.6                          0.23
# 219          329560                       256.1                          1.05
# 0            647500                        48.0                          0.00
# 211          603700                        77.4                          0.46
# 109          120540                       191.8                          2.07
# 179         1960582                        13.8                          0.13
# 32           678500                        69.8                          0.28
# 45          2345410                        26.7                          0.00
# 2           2381740                        13.8                          0.04
# 97           437072                        61.3                          0.01
# 152          923768                       142.7                          0.09
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 214           3.41                                6.50             37800.0
# 69            0.66                                4.26             27600.0
# 213           2.19                                5.16             27700.0
# 103           0.00                                3.26             28200.0
# 198           0.00                                6.40             23400.0
# 135          -4.87                               20.91              9000.0
# 11            3.98                                4.69             29000.0
# 76            2.18                                4.16             27600.0
# 101           2.07                                5.94             26700.0
# 36            5.96                                4.75             29800.0
# 189          -0.29                               61.81             10700.0
# 190           0.99                                4.42             22000.0
# 107          -0.10                               61.47              1000.0
# 161          -1.05                               31.94              5100.0
# 163          -0.49                                8.51             11100.0
# 16           -0.71                               62.60              1900.0
# 206           0.00                               41.04              6700.0
# 169           1.02                               15.39              8900.0
# 110           0.00                                7.05             17800.0
# 168          -0.13                               26.43              7000.0
# 8             0.61                               15.18             11200.0
# 191          -1.31                               14.35              3700.0
# 218          -0.04                               22.20              4800.0
# 94           -0.07                               56.29              2900.0
# 156          -2.77                               72.44              2100.0
# 43           -0.31                               20.97              6300.0
# 162          -1.50                               23.51              4600.0
# 27           -0.03                               29.61              7600.0
# 60           -0.22                               32.59              4000.0
# 210           0.00                               67.83              1400.0
# 96           -0.84                               41.58              7000.0
# 201           0.00                               20.48              7400.0
# 126           0.00                               17.70              9000.0
# 216          -1.72                               71.10              1700.0
# 141          -0.98                               41.62              4000.0
# 65            0.00                               95.32               700.0
# 145           0.00                               66.98              1400.0
# 192          -0.02                               62.50              1900.0
# 95            0.00                               35.60              3200.0
# 42           -0.40                               24.18              5000.0
# 200          -2.06                               98.54               600.0
# 224           0.00                               61.50               800.0
# 77           -0.64                               51.43              2200.0
# 219          -0.45                               25.95              2500.0
# 0            23.06                              163.07               700.0
# 211          -0.39                               20.34              5400.0
# 109           0.00                               24.04              1300.0
# 179          -2.71                               13.24             11800.0
# 32           -1.80                               67.24              1800.0
# 45            0.00                               94.69               700.0
# 2            -0.39                               31.00              6000.0
# 97            0.00                               50.25              1500.0
# 152           0.26                               98.80               900.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 214          97.0              898.0       19.13       0.22      80.65
# 69           99.0              586.4       33.53       2.07      64.40
# 213          99.0              543.5       23.46       0.21      76.33
# 103          99.0              461.2       12.19       0.96      86.85
# 198          96.1              591.0       24.00       1.00      75.00
# 135          92.2              181.6       12.99       1.31      85.70
# 11          100.0              565.5        6.55       0.04      93.41
# 76           99.0              667.9       33.85       0.59      65.56
# 101          98.6              430.9       27.79       9.53      62.68
# 36           97.0              552.2        4.96       0.02      95.02
# 189          86.4              107.0       12.08       0.79      87.13
# 190          97.9              453.5       26.07       9.87      64.06
# 107          85.1                8.1        8.08       0.98      90.94
# 161          90.9               79.5        2.89       0.40      96.71
# 163          99.8              306.3       45.91       1.12      52.97
# 16           43.1                7.3       62.11       3.07      34.82
# 206          86.5              269.5       30.93       3.31      65.76
# 169          99.6              280.6        7.33       0.11      92.56
# 110          97.9              486.1       17.18       1.95      80.87
# 168          98.4              196.9       40.82       2.25      56.93
# 8            97.1              220.4       12.31       0.48      87.21
# 191          92.3               61.5       13.86      15.70      70.44
# 218          93.4              140.1        2.95       0.92      96.13
# 94           59.5               45.4       54.40       2.74      42.86
# 156          45.7               31.8       27.87       0.87      71.26
# 43           92.5              176.2        2.42       1.67      95.91
# 162          92.6               38.4       18.95      16.77      64.28
# 27           86.4              225.3        6.96       0.90      92.15
# 60           57.7              131.8        2.87       0.48      96.65
# 210          69.9                3.6       25.88      10.65      63.47
# 96           79.4              276.4        8.72       1.39      89.89
# 201          92.6              108.9       29.36       6.46      64.18
# 126          88.7              179.0        5.48      17.61      76.91
# 216          99.3               62.9       10.83       0.83      88.34
# 141          51.7               40.4       19.61       2.17      78.22
# 65           42.7                8.2       10.71       0.75      88.54
# 145          45.2               15.9       21.68       0.64      77.68
# 192          61.1               16.3        6.83       0.18      92.99
# 95           87.9               52.0       11.32       7.23      81.45
# 42           90.9              266.7       15.40       1.25      83.35
# 200          78.2                4.0        4.52       1.08      94.40
# 224          50.2               37.2        2.78       0.24      96.98
# 77           74.8               14.4       16.26       9.67      74.07
# 219          90.3              187.7       19.97       5.95      74.08
# 0            36.0                3.2       12.13       0.22      87.65
# 211          99.7              259.9       56.21       1.61      42.18
# 109          99.0               42.4       20.76       2.49      76.75
# 179          78.8              140.6        1.67       0.09      98.24
# 32           85.3               10.1       15.19       0.97      83.84
# 45           65.5                0.2        2.96       0.52      96.52
# 2            70.0               78.1        3.22       0.25      96.53
# 97           40.4               38.6       13.15       0.78      86.07
# 152          68.0                9.3       31.29       2.96      65.75
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 214      3.0      14.14       8.26        0.010     0.204    0.787
# 69       4.0      11.99       9.14        0.022     0.214    0.764
# 213      3.0      10.71      10.13        0.005     0.237    0.758
# 103      3.0       9.37       9.16        0.017     0.258    0.725
# 198      2.0      12.56       6.48        0.018     0.259    0.723
# 135      1.5      20.69       4.74        0.038     0.259    0.702
# 11       1.0      12.14       7.51        0.038     0.262    0.700
# 76       3.0       8.25      10.62        0.009     0.296    0.695
# 101      NaN       8.72      10.40        0.021     0.291    0.688
# 36       NaN      10.78       7.80        0.022     0.294    0.684
# 189      1.0      18.20      22.00        0.025     0.303    0.671
# 190      3.0      10.06       9.72        0.040     0.295    0.665
# 107      1.5      39.72      14.02        0.163     0.188    0.651
# 161      1.5      20.48       6.23        0.080     0.270    0.650
# 163      3.0       9.85       9.89        0.050     0.311    0.640
# 16       2.0      29.80       8.27        0.199     0.198    0.603
# 206      3.0      16.62       5.97        0.117     0.298    0.585
# 169      NaN       9.95      14.65        0.054     0.371    0.575
# 110      3.0      10.00       5.85        0.033     0.403    0.563
# 168      3.0      10.70      11.77        0.101     0.350    0.549
# 8        3.0      16.73       7.55        0.095     0.358    0.547
# 191      2.0      15.51       6.52        0.178     0.276    0.545
# 218      2.0      18.71       4.92        0.040     0.419    0.541
# 94       2.5      22.01       8.18        0.186     0.276    0.538
# 156      1.0      29.74       8.23        0.216     0.251    0.533
# 43       2.0      20.48       5.58        0.125     0.342    0.533
# 162      2.0      24.89       5.41        0.144     0.326    0.530
# 27       2.0      16.56       6.17        0.084     0.400    0.516
# 60       1.0      22.94       5.23        0.149     0.357    0.493
# 210      2.0      47.35      12.24        0.311     0.222    0.469
# 96       1.0      17.00       5.55        0.116     0.424    0.460
# 201      2.0      13.87       7.04        0.099     0.441    0.460
# 126      2.0      22.86       5.05        0.084     0.480    0.436
# 216      1.0      26.36       7.84        0.342     0.229    0.430
# 141      NaN      21.98       5.58        0.217     0.357    0.426
# 65       2.0      37.98      14.86        0.475     0.099    0.426
# 145      NaN      30.98       9.31        0.380     0.210    0.410
# 192      2.0      34.53       8.97        0.387     0.203    0.410
# 95       2.0      20.34       6.25        0.134     0.458    0.408
# 42       1.5      13.25       6.97        0.125     0.473    0.403
# 200      NaN      37.71      16.39        0.432     0.172    0.396
# 224      1.0      42.89       8.30        0.135     0.472    0.393
# 77       2.0      30.52       9.72        0.366     0.246    0.387
# 219      2.0      16.86       6.22        0.209     0.410    0.381
# 0        1.0      46.60      20.34        0.380     0.240    0.380
# 211      3.0       8.82      14.39        0.187     0.452    0.361
# 109      3.0      15.54       7.13        0.300     0.340    0.360
# 179      1.0      29.34       2.58        0.033     0.613    0.354
# 32       2.0      17.91       9.83        0.564     0.082    0.353
# 45       2.0      43.69      13.27        0.550     0.110    0.340
# 2        1.0      17.14       4.61        0.101     0.600    0.298
# 97       1.0      31.98       5.37        0.073     0.666    0.261
# 152      1.5      40.43      16.94        0.269     0.487    0.244

# %%
# let's make our view a little cleaner - I only want to see the Country, Population and the ratio of Service industry
large_service_countries[["Country", "Population", "Service"]]
# Out:
#                Country  Population  Service
# 214     United States    298444215    0.787
# 69             France     60876136    0.764
# 213    United Kingdom     60609153    0.758
# 103             Japan    127463611    0.725
# 198            Taiwan     23036087    0.723
# 135            Mexico    107449525    0.702
# 11          Australia     20264082    0.700
# 76            Germany     82422299    0.695
# 101             Italy     58133509    0.688
# 36             Canada     33098932    0.684
# 189      South Africa     44187637    0.671
# 190             Spain     40397842    0.665
# 107             Kenya     34707817    0.651
# 161              Peru     28302603    0.650
# 163            Poland     38536869    0.640
# 16         Bangladesh    147365352    0.603
# 206            Turkey     70413958    0.585
# 169            Russia    142893540    0.575
# 110      Korea, South     48846823    0.563
# 168           Romania     22303552    0.549
# 8           Argentina     39921833    0.547
# 191         Sri Lanka     20222240    0.545
# 218         Venezuela     25730435    0.541
# 94              India   1095351995    0.538
# 156          Pakistan    165803560    0.533
# 43           Colombia     43593035    0.533
# 162       Philippines     89468677    0.530
# 27             Brazil    188078227    0.516
# 60              Egypt     78887007    0.493
# 210            Uganda     28195754    0.469
# 96               Iran     68688433    0.460
# 201          Thailand     64631595    0.460
# 126          Malaysia     24385858    0.436
# 216        Uzbekistan     27307134    0.430
# 141           Morocco     33241259    0.426
# 65           Ethiopia     74777981    0.426
# 145             Nepal     28287147    0.410
# 192             Sudan     41236378    0.410
# 95          Indonesia    245452739    0.408
# 42              China   1313973713    0.403
# 200          Tanzania     37445392    0.396
# 224             Yemen     21456188    0.393
# 77              Ghana     22409572    0.387
# 219           Vietnam     84402966    0.381
# 0         Afghanistan     31056997    0.380
# 211           Ukraine     46710816    0.361
# 109      Korea, North     23113019    0.360
# 179      Saudi Arabia     27019731    0.354
# 32              Burma     47382633    0.353
# 45   Congo, Dem. Rep.     62660551    0.340
# 2             Algeria     32930091    0.298
# 97               Iraq     26783383    0.261
# 152           Nigeria    131859731    0.244

# %% [markdown]
# ####  Your turn! 🚀 Explore your `DataFrame` and run some analysis 🤓
#
# Some ideas:
# * check which countries have the warmest climate ☀️
# * let's check the tiny countries! make a variable to store countries with Population < 3_000_000
# * Beach life! 😎check the countries with longest Coastline. Remember to type the full column name!
# * Are these coastal countries always online? 📱Let's sort them by amount of Phone usage. Again, check the full column name!
# #### ...and anything else you want to analyze! 🚀
#
# How? Type in your code on the empty line below and press `Shift` + `enter/return ⏎` keys to run it

# %% [markdown]
# # !!! SPLITTING FROM MICHAEL'S HERE

# %% [markdown]
# ## String Concatenation
#
#     first_name = "John"
#     last_name = 'Lennon'
#
#     full_name = first_name + last_name

# %% [markdown]
# ## Conditionals
#
#     1. if condition:
#         statemnt
#
#     2. if condition:
#         statement
#     else:
#         statement
#
#     3. if condition 1:
#          statement 1
#        elif condition 2:
#          statement 2
#          .
#          .
#          .
#        (else:
#           statement n)          # optional

# %% [markdown]
# ## Loops
#
#     1. while condition:    # usually loops so long as condition is true
#            statement
#
#     2. for __ in __        # usually loops finite times
#            statement

# %% [markdown]
# ## Input / Output   input()    print()
#
#     a = input()
#     a = input("what is your name? ")
#     print("wo ai zhongguo")

# %% [markdown]
# # CHALLENGES

# %% [markdown]
# ## 1. Microwave Oven
# Specs:
# - Implement a microwave oven program that asks user what kind of food does he/she wants to heat.
# - If the user wants to heat up noodles, send a message to the customer that ”I am heating up noodles”
# - If the user wants to heat up rice, send a message to the customer that ”I am heating up rice”
#
# Eg.
#
# => Which kind of food do you want to heat up?        noodles
#
# => I am heating up noodles!

# %% [markdown]
# ## 2. Super Microwave Oven
# Specs:
# - If the customer wants to heat up noodles, tell him/her this is going to cost 2 seconds.
# - If the customer wants to heat up rice, tell him/her this is going to cost 5 seconds.
# - Until the food is ready, send a message to the customer that the food is ready.
#
# Eg.
#
# =>Which kind of food do you want to heat, noodles/rice? noodles
#
# =>This is going to cost 2 seconds….
#
# =>noodles are ready!!

# %% [raw]
# # HINT:
#
# import time
#
# time.sleep(n)                # forces the running of the code to delay/sleep for n seconds

# %% [markdown]
# ## 3. Microwave Oven PRO
# Specs:
# - Ask the user which food he/she wants to heat and for how long?
# - Then count the time to tell the user how much time spent.
# - Once down, tell the user food is ready!
#
# Eg.
#
# =>Which one do you want to heat, noodles/rice?   noodles
#
# =>how many seconds does it take?    5
#
#     Cooking…
#     0
#     1
#     2
#     3
#     4
#     5
#     Your food is ready!

# %% [raw]
# # HINT:
#
# import time
# time.sleep(n)                # forces the running of the code to delay/sleep for n seconds
